# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor1010xd/Gonzalez-Aguilar-Victor-Hugo-structured-programming/blob/main/Lab2_Gonzalez_Victor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code 1

# %%
def multiply(a, b):
   return a * b
print(multiply(3,4))
# Out:
# 12

# %% [markdown]
# Code 2

# %%
counter = 0
for i in range(4):
    counter = counter + 1
print(counter)
# Out:
# 4

# %% [markdown]
# Code 3

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Adult")
# Out:
# Enter your age: 18
# Adult

# %% [markdown]
# Code 4

# %%
a = 3
b = 4
temp = a
a = b
b = temp
print(a)
print(b)
# Out:
# 4
# 3

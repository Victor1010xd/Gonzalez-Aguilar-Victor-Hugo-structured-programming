# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor1010xd/Gonzalez-Aguilar-Victor-Hugo-structured-programming/blob/main/Lab1_Gonzalez_Victor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code A

# %%
grades= (80,90,70)
average= sum(grades)/len(grades)
print(average)
# Out:
# 80.0

# %% [markdown]
# Code B

# %%
def calculate_average(data):
    return sum(data)/len (data)
grades=(80,90,70)
print(calculate_average(grades))
# Out:
# 80.0

# %% [markdown]
# Code C

# %%
numbers=(1,2,3,4,5)
squares=list(map(lambda x: x**2,numbers))
print (squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Modified Program

# %%
grades= (50,100,30,70,70)
average= sum(grades)/len(grades)
print(average)
# Out:
# 64.0
